# %% [markdown]
# **Machine Learning model on Life Expectancy**

# %% [markdown]
# *Importing Necessary Packages*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Importing the dataset*

# %%
df=pd.read_csv('Life_Expectancy_Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# *Handling with Missing Values*

# %%
#removing the null values
df = df[df["Life expectancy "].isnull()==False]
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
#Remodelling the categorical data into numerical data
from sklearn.preprocessing import LabelEncoder
labeller=LabelEncoder()
df['Country']=labeller.fit_transform(df['Country']).astype(int)
df['Status']=labeller.fit_transform(df['Status']).astype(int)
df.head()
# Out:
#    Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0        0  2015       1              65.0            263.0             62
# 1        0  2014       1              59.9            271.0             64
# 2        0  2013       1              59.9            268.0             66
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      0
# Adult Mortality                      0
# infant deaths                        0
# Alcohol                            193
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                32
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                443
# Population                         644
#  thinness  1-19 years               32
#  thinness 5-9 years                 32
# Income composition of resources    160
# Schooling                          160
# dtype: int64

# %%
#Filling null values using KNN algorithm
from sklearn.impute import KNNImputer
imputer=KNNImputer(n_neighbors=5)
cdf=imputer.fit_transform(df)
cdf=pd.DataFrame(cdf,columns=df.columns)
cdf.head()
# Out:
#    Country    Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0      0.0  2015.0     1.0              65.0            263.0           62.0
# 1      0.0  2014.0     1.0              59.9            271.0           64.0
# 2      0.0  2013.0     1.0              59.9            268.0           66.0
# 3      0.0  2012.0     1.0              59.5            272.0           69.0
# 4      0.0  2011.0     1.0              59.2            275.0           71.0
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0    1154.0  ...    6.0
# 1     0.01               73.523582         62.0     492.0  ...   58.0
# 2     0.01               73.219243         64.0     430.0  ...   62.0
# 3     0.01               78.184215         67.0    2787.0  ...   67.0
# 4     0.01                7.097109         68.0    3013.0  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
cdf.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# *<br>*

# %% [markdown]
# *Plotting graps to visualize*

# %%
#printing a heatmap
corr=cdf.corr()
plt.tight_layout()
plt.figure(figsize=(15,10))
plt.title("Correlation Matrix")
sns.heatmap(corr,annot=True,cmap='viridis')
plt.show()

# %%
sns.pairplot(cdf[['Country','Year','Status','Life expectancy ']])
plt.show()
# Out:
# /home/rguktvalley/.local/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(20,10))
sns.barplot(cdf[cdf.columns[:15]])
plt.show()

# %%
plt.figure(figsize=(15,10))
res=sns.histplot(cdf[['Life expectancy ']],bins=30)
bars=res.patches
bar_heights = [bar.get_height() for bar in bars]
bar_centers=[each.get_x()+each.get_width()/2 for each in bars]
plt.plot(bar_centers,bar_heights, color='red', linestyle='-.')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(cdf[cdf.columns[:15]])
plt.show()

# %% [markdown]
# **Working on models Building**

# %% [markdown]
# *Splitting the data*

# %%
#Splitting the data for both training and testing
from sklearn.model_selection import train_test_split
x=cdf.drop(['Life expectancy '],axis=1)
y=cdf[['Life expectancy ']]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %% [markdown]
# *Building linear regression model*

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
print("x_train_scaled:",x_train_scaled.shape)
print("x_test_scaled:",x_test_scaled.shape)
# Out:
# x_train_scaled: (2342, 21)
# x_test_scaled: (586, 21)

# %%
pca=PCA(n_components=2)
x_train_pca=pca.fit_transform(x_train_scaled)
x_test_pca=pca.transform(x_test_scaled)
print("x_train_pca:",x_train_pca.shape)
print("x_test_pca:",x_test_pca.shape)
# Out:
# x_train_pca: (2342, 2)
# x_test_pca: (586, 2)

# %%
#linear regression
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train_pca,y_train)
# Out:
# LinearRegression()

# %%
#Printing the coefficients
print("The Intercept is: ",model.intercept_)
print("The Coefficients is: ",model.coef_)
# Out:
# The Intercept is:  [69.19820666]
# The Coefficients is:  [[-3.05548825  1.66842352]]

# %%
#predicting the values
yhat=model.predict(x_test_pca)
yhat[0:5]
# Out:
# array([[64.46895099],
#        [67.25723342],
#        [62.32114225],
#        [78.02702235],
#        [75.97372712]])

# %%
#printing the errors
from sklearn import metrics
print("Mean absolute Error is: ",metrics.mean_absolute_error(yhat,y_test))
print("Mean Squared Error is: ",metrics.mean_squared_error(yhat,y_test))
print("R2_score is: ",metrics.r2_score(yhat,y_test))
# Out:
# Mean absolute Error is:  3.8313811103116073
# Mean Squared Error is:  24.467208682805946
# R2_score is:  0.5957223665859495

# %% [markdown]
# **Model Built Successfully**
